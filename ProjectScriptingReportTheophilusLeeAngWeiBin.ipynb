# %% [markdown]
# <P> <img src="https://i.ibb.co/gyNf19D/nhslogo.png" alt="nhslogo" border="0" width="100" align="right"><font size="6"><b> CS6131 Database Design</b> </font>

# %% [markdown]
# # Project Scripting Phase Report Submission

# %% [markdown]
# ### By Ang Wei Bin and Theophilus Lee Khong Yoon

# %% [markdown]
# ### Submission Instructions

# %% [markdown]
# <div class="alert alert-block alert-info">
#
# * You will need to submit the following files in your final project submission:
#     * Your Jupyter Notebook report. Name the report `ProjectScriptingReport<YourName>.ipynb`.
#     * All relevant image files to be displayed in this report (make sure you use relative file referencing and the image will display in another computer).
#     * Attached each file one by one and upload on Coursemology.
# * Please print a copy of the final report to OneNote Individual Notebook space > Project. Double check on the image resolution. If the resolution is poor, please copy and paste the ORIGINAL clear image into the OneNote page (paste at the side of the printed image).
#
# * Any submission that fails to comply to the above instructions will result in upto 5% penalty.
#
# * You may wish to refer to the following reference to help organize and "beautify" your final report here. <br>
# https://thecodingbot.com/markdown-in-jupyter-ipython-notebook-cheatsheet/
# </div>

# %% [markdown]
# ### Notebook link

# %% [markdown]
# <a href="https://deepnote.com/workspace/picocanvas-9174b5b9-b706-4a32-8ef1-61da40e07405/project/weibintheo-3fe41874-99e0-4e33-9fd6-e7ae9af26c36/notebook/ProjectScriptingReportWeiBinTheo-c0fb5043a2c04ab490b39cf107b84d04?utm_source=share-modal&utm_medium=product-shared-content&utm_campaign=notebook&utm_content=3fe41874-99e0-4e33-9fd6-e7ae9af26c36">Link to Deepnote Notebook<a>

# %% [markdown]
# ### Section A: Executive Summary

# %% [markdown]
# <div class="alert alert-block alert-warning">
# Include your updated Executive Summary writeup here. Any changes from previous submission should be highlighted.
# You may consider using HTML editor for easy editing e.g. <a href="https://onlinehtmleditor.dev/">https://onlinehtmleditor.dev/</a>
# </div>

# %% [markdown]
# - [x] <mark>Clear Objectives, Users, and Justification</mark>
# - [x] <mark>Clarity of Value Proposition: While the summary touches on the benefits for different user groups (data science researchers, UX researchers), it could be more explicit in stating the key benefits for each. For instance, instead of stating "Easier to observe patterns in low level inputs," provide a specific example of how this capability helps researchers uncover insights they couldn't obtain otherwise. Similarly, when talking about UX Researchers.</mark>

# %% [markdown]
# **Overview**
# Advanced tools for tracking and analyzing user behavior on websites such as Sentry exist. However, we find that Sentry is more concerned with modelling the high level interactions of users with websites, for use in debugging. On the other hand, we believe that there is value in desiging a low level model of user browsing behaviour. Complex interactions between a user and a website cannot always be captured on a high level interpretation. For instance, Sentry's capability to interface with video controls has the following problems: a website front-end designer may decide that serving videos in a custom element is suitable. In that case, Sentry may face issues recording use of video control. However, a recording of only low level user input (click, drag, etc) will form a consistent pattern that is indenpendant of website implementation. Therefore, there are benefits to our approach over Sentry's.
#
# We take inspiration from the work produced by this recent paper: https://huggingface.co/datasets/McGill-NLP/WebLINX. WebLINX has opened new doorways when it comes to training on browsing data, allowing AI models to mimic human browsing. However, the data collected is still on a small scale and is fairly complex to handle. A database management system designed solely for gathering user browsing data can streamline the process of data collection and inference. Hence, the database is useful in real life context.
#
# **Goals**
#
# - Allow users to record their browsing sessions in-system to be uploaded to the database.
# - Allow researchers to conduct research efficiently.
# - Allow database administrators the power to manage database.
#
# **Target Users**
#
# The database application's target audience are data science researchers, specifically, people specializing in web analytics or clickstream Analytics. UX Researchers may also find use in our database.
#
# _Data Science Researchers_
# - Easier to observe patterns in low level inputs than inputs that may have more complex meaning. <mark>By storing information about inputs in a easily accessible format, researchers will be able to easily access and analyze the data. Researchers can easily filter out precisely what data they want to look at at apply operations by using the search function of the database. In specific, consider if we were to store the raw requests captured by the browser, a higher level interpretation of the communication between user and server through the browser. Constructing complex queries would require us to first dissect the meaning of requests, an issue that a low level representation will not face. </mark>
#
# _UX Researchers_
# - Useful for understanding how design tokens affect user interaction. <mark>The researchers can query from the database information about interactions related to specific parts of the UI to determine how changes influence user interaction. This is important for the case of design tokens, which operate at the level of System tokens, which determine basic attributes such as color and typography, to Component tokens which determine how the UI is composed. A low level representation allows us to take a bottom up approach to understanding how design tokens affect user interaction.</mark>
#
# _Machine Learning_
# - While we do not address directly, it is certainly possible to train models on our database. <mark>Our database gives a way to store user interaction data in a way that is easily inputable into a machine. This means that interested people can easily use it to train machine learning models related to user inputs.</mark>
#
#
# **Justification for using RDBMS**
# - On a high level understanding, the entities associated with a browsing session are highly related with each other. For example, a user click is inherently associated with a web page that the user is browsing on, and the html element that the user clicks on, and of course, the user click is associated with a user. This forms a rigid relationship between entities that we find is most efficiently represented by a relational schema.
# - A Relational Database Management System favours scaling vertically (i.e. adding more server resources). This is ideal as our users consist mainly of individual researchers who are likely to have such a system, rather than a large audience of concurrent consumers accessing the database, in which case horizontal scaling would be preferred.
# - A researcher would benefit from the greater ease of performing join queries in database management systems.
# - A consistent schema is beneficial for tracking historical user data (i.e. we can still perform research across many years since the base schema does not change)

# %% [markdown]
# ### Section B: Business Rules

# %% [markdown]
# <div class="alert alert-block alert-warning">
# Include your updated Business Rules writeup here. Any changes from previous submission should be highlighted.
# You may consider using HTML editor for easy editing e.g. <a href="https://onlinehtmleditor.dev/">https://onlinehtmleditor.dev/</a>
# </div>

# %% [markdown]
# <p><span style="font-size:16px"><span style="font-family:Arial,Helvetica,sans-serif">e.g. This is a test. <span style="background-color:#ffff00">The statement I have edited is this.</span></span></span></p>

# %% [markdown]
# - [x] <mark>The set of business rules is strong, demonstrating a good understanding of the domain and the system's data model: Noted</mark>
# - [x] <mark>Linking to Real-World Operations (Context): While the rules define entities and relationships, some rules could benefit from explicitly connecting these concepts to real-world user behaviors or system functions. For instance, explaining why "2 Replays cannot contain the same UserEvent" in terms of data integrity or preventing duplication would add value.</mark>

# %% [markdown]
# **Some Considerations**
# - Position in DOM influences event execution order in the browser due to Event Bubbling and Event Capturing. We are not considering this for the database.
#
# **Users**
# Users are website accounts. Users contain an email address, user id, username, password, <mark>date and time of account creation, date and time of last login, status of account (whether the account is enabled or disabled), full name, phone number, role as either user or admin, whether email has been verified, number of failed login attempts and whether 2FA is enabled</mark>. the email address is further split into email name and email domain. <mark>The name is further split into first name, middle name and last name.</mark> A User is capable of creating many Replays. A User may create no Replays, and every Replay must be created by a User.
#
#
# **Replay**
# Replays contain a snapshot of a recorded browsing session. UserEvents may take place in a Replay. A Replay may contain many UserEvents. A Replay can have no UserEvents. 2 Replays cannot contain the same UserEvent.
#
# <mark>This is because a Replay represents a recorded session that doesnt not overlap with other Replays. This also makes sure information about a UserEvent is not duplicated.</mark>
#
# Every Replay must contain exactly one of each of the following: unique replay id, time, browser agent, device type, device os, user ip address, default viewport. <mark>We have determined that these are key attributes that are shared across a wide variety of browser sessions, and therefore we do not list other capturable data in our database. </mark>default viewport represents the dimensions of the viewport, and is further subdivided into width and height. <mark>We do note that we could further constraint the viewport size to a preset list of valid viewport sizes, since it is known what screen resolutions exist and it is a common standard. However, we choose not to impose this constraint to future-proof our database design. </mark>. IP address is further divided into network id and host id in accordance to ip address format. Device Operating system is further split into os type and os version. Browser agent is the User-Agent header provided by the browser and is further subdivided into product, product version and comment, following user agent schema. time is split into the starting time and the ending time. All time is measured in milliseconds elapsed since the UNIX epoch.
#
# **UserEvent**
# The database stores information about user events, where each UserEvent is an atomic browser action issued by a device due to user input. We will not be considering script-triggered events/inputs for this database. UserEvents are associated with Replays<mark>, becauase UserEvents only have meaning when they are performed on a browser, i.e. on a Replay</mark>. Every UserEvent must have a Replay<mark>, because without a Replay a UserEvent has no meaning</mark>. Many UserEvents can be associated with the same Replay<mark>Since a user can perform many actions on the same browser</mark>. UserEvents have a timestamp. Timestamps are measured in milliseconds elapsed since the UNIX epoch. Since it is reasonable to assume that a user cannot perform 2 inputs in the same millisecond, we can say that any 2 UserEvent timestamps are unique within a Replay. However, 2 UserEvent timestamps from 2 different Replays are not guaranteed to be unique Each UserEvent also has 1 status determining the state of the action. The possible states are <mark>complete, active, timeout<mark>. Each UserEvent must contain a viewport width and height<mark>since browsers can resize and we must account for the relative positioning</mark>. A UserEvent results in a Webstate. Every UserEvent must have a Webstate. Only 1 Webstate can be associated with a UserEvent<mark>, since a user cannot perform an action that affects 2 different browsers</mark>. There are many types of UserEvents. The types in consideration are 'NavigateEvent', 'ElementEvent'. Not every UserEvent must be one of the types, and a UserEvent may only have 1 type.
#
# **NavigateEvent**
# Some user events involve a change in route or domain of the web page, or in other words, a change in URL. We define these events to be called NavigateEvents. NavigateEvents are a type of UserEvent. NavigateEvents must contain at most 1 URL<mark>, since a user cannot go to 2 different websites at the same time</mark>. Every NavigateEvent must have a URL<mark>, since a user must be going to a website to navigate</mark>.
#
# **ElementEvent**
# Some user events may involve 1 or more elements. We define these events to be called ElementEvents. ElementEvents are a type of UserEvent. ElementEvents have participating Elements. Not every ElementEvent has participating Elements. An ElementEvent may be associated with more than 1 Element. Many ElementEvents may be associated with the same Element<mark>, since a user may for instance, click or drag the same button multiple times</mark>. There are many types of ElementEvents. The types in consideration are 'TextEvent', 'MoveEvent', 'ClickEvent'. Not every ElementEvent must be one of the types, and an ElementEvent may only have 1 type<mark>, since if a user were to perform a click and a drag at the same time, we would consider them as 2 separate events.</mark>.
#
# **TextEvent**
# TextEvent describes a change in text on a web page due to user or scripted input. TextEvents are a type of ElementEvent. TextEvents have new text to update the participating elements with. TextEvents must have a new text.
#
# **ClickEvent**
# ClickEvent describes a click input on a web page. ClickEvents are a type of ElementEvent. Each ClickEvent must contain x and y click coordinates. Each ClickEvent has a mouse button id. This corresponds to either the left, right, or middle mouse button. Each ClickEvent must have a mouse button id. Each ClickEvent must contain only 1 mouse button id<mark>, since an input device for clicking (a mouse) may not input both a left and right click at the same time, only one after the other</mark>.
#
# **MoveEvent**
# MoveEvent describes a movement of the cursor on the web page. MoveEvents are a type of ElementEvent. Each MoveEvent must contain exactly 1 x begin and y begin scroll coordinates. Each MoveEvent must contain exactly 1 x end and y end scroll coordinates. There are many types of MoveEvents. The types in consideration are 'ScrollEvent', 'DragEvent'. A MoveEvent may be either, none, or both of these types<mark>This is because a user may scroll and drag on a web page at the same time</mark>.
#
# **ScrollEvent**
# ScrollEvent describes a scroll input on a web page. ScrollEvents are a type of MoveEvent. ScrollEvents must contain the distance scrolled horizontally and vertically. This is stored as a fraction of the page width and height respectively. ScrollEvents may only scroll a participating element<mark>This is because browsers keep track of the context that our user is interacting with the DOM, and will only scroll the context that our user is interacting with, which is our participating element</mark>.
#
#
# **DragEvent**
# DragEvent describes a change in the position of the web page, with a mouse button in the down state. DragEvents are a type of MoveEvent. Each DragEvent begins and ends when the mouse button is pressed and released. DragEvents are a type of MoveEvent. Each DragEvent may only drag a participating element on the web page<mark>This is because, again, browsers keep track of the context that our user is interacting with the DOM, and will only drag the context that our user is interacting with, which is our participating element</mark>.
#
# **Element**
# Elements are entities that represent the elements on the website that the user interacts with. These entities are cherry picked heuristically to be relevant to user interaction<mark>, because websites often have many elements that are not relevant to user interaction, such as metadata or stylesheets</mark>. Elements may participate in ElementEvents. Many Elements can participate in many ElementEvents. Not every Element must participate in ElementEvents<mark>, since not all elements have an interaction function for the user</mark>. Elements are also contained within a Webstate. Many Elements may be contained within a webstate. 2 Webstates may contain the same element, <mark>, since 2 webstates may be 2 slightly different iterations of the same replay, and hence may contain the same element</mark>. An Element must be contained in a Webstate. Elements have uids. Any 2 Elements within a Webstate will not share uids<mark>. This ensures entity integrity</mark>. 2 Elements from different Webstates may share the same uid<mark>, since 2 webstates may be 2 iterations of the same replay</mark>. An element has an element_id used as a key. An element must have 1 tag referring to its html element tag. All valid HTML tags are valid tags<mark>, including deprecated tags, so as to preserve backwards compatibility</mark>. Elements contain a xpath which identifies location of element in the page by traversing the DOM. XPath is needed in calculating the element order.Elements contain text which represent the text content in the html element. Elements contain an uid. Bounding boxes are further divided into x and y coordinates and a height and width<mark>, since all interactable html elements have a defined bounding box within the DOM</mark>. Elements may also contain many html attributes. Elements also contain a z_index, which identifies the layer on which the Elements exists on the web page.
#
# **Cookies**
# Cookies store website information used for authentication and user tracking among other uses. Cookies are associated with Webstates. Many Cookies may be associated with many Webstates<mark>, since cookies persist across the website and path</mark>. Cookies must be associated with a Webstate. Any 2 Webstates may contain the same Cookie. Cookies have a unique name. <mark>This ensures there is entity integrity. </mark> Cookies store whether they are secure, whether they are http_only and whether they are from the same site. Cookies store the following attributes: size, expiry, path, domain, value. Cookies store when they were last accessed.
#
# **Webstate**
# Webstates store minified html web pages. Webstates may contain Cookies. Many Webstates may contain many Cookies. Webstates may contain no Cookies. 2 Webstates may contain the same Cookie. Webstates are associated with a UserEvent. Not every Webstate must have a Userevent. Every Webstate must contain at most 1 UserEvent. 2 Webstates may not contain the same UserEvent. Webstates contain Elements. Each Webstate contains many elements. Each Webstate must contain at least 1 element. 2 Webstates may not contain the same element. A Webstate has a html hash. This stores the hash of the minified html of the web page. The hash is guaranteed to be unique<mark>, since it is unlikely that there will be a hash collision for 2 different web pages</mark>. Webstates contain a html filepath, which locates the physical minified html file on a LFS system, and is composed of a base path concatenated to the html hash.
#
# **Participating Elements**
# Elements that participate in ElementEvents have an Element Order. The order value is calculated from the z_index and position within the DOM of each element, and then each element is sorted by the order value to get the element order.

# %% [markdown]
# ### Section C: EER Model

# %% [markdown]
# <div class="alert alert-block alert-warning">
# Screen shot your previous ER (with teacher's marking) and insert image below (double click on the markdown and insert your img name).
# </div>

# %% [markdown]
# <img src="CS6131-Project-ER.png">

# %% [markdown]
# <div class="alert alert-block alert-warning">
# Attached the image of your UPDATED ER Model here. Highlight changes made.
# </div>

# %% [markdown]
# <mark> Changes highlighted at the end of section D. </mark>

# %% [markdown]
# <img src="CS6131-Project-ER-Updated.png">

# %% [markdown]
# https://online.visual-paradigm.com/share.jsp?id=333833343832332d32

# %% [markdown]
# ### Section D: Relational Model

# %% [markdown]
# <div class="alert alert-block alert-warning">
# Screen shot your previous Relational Model (with teacher's marking) and insert image below.
# </div>

# %% [markdown]
# <img src="CS6131-Project-RelationalModel.png">

# %% [markdown]
# <div class="alert alert-block alert-warning">
# Attached the image of your UPDATED Relational Model here.  Highlight changes made.
# </div>

# %% [markdown]
# <img src="CS6131-Project-RelationalModel-Updated.png">

# %% [markdown]
# https://online.visual-paradigm.com/share.jsp?id=333833343832332d35

# %% [markdown]
# - [x] <mark>We change mouse_id to mouse_button_id for better clarity</mark>
# - [x] <mark>Our work does not contain a viewport entity, nor a position entity. Therefore, we hold that clickevent does not have a relation with viewport, and cannot have a relationship with position. No changes made. </mark>
# - [x] <mark>We modify the original EER and Relational Model to use positions in the clickevent, by turning it into a composite attribute.</mark>
# - [x] <mark>We have acknowledged that some entities such as User are too generalized, and therefore have added more attributes so as to better capture the basic requirements needed for making a comprehensive user experience.</mark>
# - [x] <mark>We have taken care to account for the different subtypes of user event with their individual attributes. No changes made.</mark>

# %% [markdown]
# <div class="alert alert-block alert-warning">
# Justify your mapping strategy from ER to relational, particularly if the approach deviates from the norm, or you have inheritance in your ER model (i.e. which strategy is adopted for inheritance mapping and why).
# </div>

# %% [markdown]
# **Approaches that deviate from norm**
# There are some pecularities that may stand out in the mapping from ER to relational model, but they do not deviate from the norm. We will explain them here.
#
# EventParticipatingElements Entity can be observed to have a composite key composing 4 key attributes. This is result of the following: ElementEvent and Element are related in a M to N relationship, with Element being a weak entity, and ElementEvent inheriting from a weak entity. Therefore, we first use Mapping of Binary M:N Relationship Types to define EventParticipatingElements, containing weak keys timestamp and uid from ElementEvent and Element respectively. Then, we use Mapping of Weak Entity Types to include the respective strong keys, html_hash and replay_id.
#
# There is also the high volume of weak entities present in the relational model and subsequently ER diagram. This is because in a webpage, most elements (cookies, html elements, events) have no meaning when taken out of their context (webpage). Therefore, it is necessary to represent this in the relational model. For instance,  UserEvent is inherently dependent on context (Replay) to exist within the subject domain.
#
# **Specialization and Generalization**
# _UserEvent_ is a superentity of NavigateEvent and ElementEvent. We chose the Multiple Relations-superclass and subclasses method for convertion to Relational Model. This is for the following reasons:
# There are many possible input events, even on a low level interpretation, due to the wide range of input devices not covered here (pressure-sensitive touchpad, controller, etc.). Therefore, it is important to allow for ease of extension of the relational model. To achieve this, we must have a Generic UserEvent to offer minimal functionality for subclasses not defined in our relational model, which can then be updated to a specific subclass in the relational model when needed.
# Also, it is important to note that events in Javascript are typically handled in a JSON-like format, and each only contain used attributes. Therefore, single relation with type attribute or 1 hot encoded attribute are not appropriate, since it will create unnecessary null values in the database, wasting space.
#
# _ElementEvent_ is a superentity of ClickEvent, TextEvent and MoveEvent. We chose the Multiple Relations-superclass and subclasses method. This is for the following reasons:
# The same reasons from UserEvent will also apply here. Additionally, ElementEvent subclasses often contain position attributes, which may be confused with each other if they are combined into 1 relation.
#
# _MoveEvent_ is a superentity of DragEvent and ScrollEvent. We chose the Multiple Relations-superclass and subclasses method. This is for the following reasons:
# The same reasons from UserEvent will also apply here.

# %% [markdown]
# <div class="alert alert-block alert-warning">
# If the relational schema mapped from the ER is not in 3NF, propose relevant normalization to make all relations in 3NF. You may leave this part blank if no further normalization is required.
# </div>

# %% [markdown]
# Proposed normalization, if any

# %% [markdown]
# ### Section E: DDL Schema

# %% [markdown]
# <div class="alert alert-block alert-warning">
# Fill in the relevant code required to create the relations for your database based on the relational model in the previous section. <br>
# Your code should be end to end (i.e. I should be able to execute on my computer without much problem).
# Please ensure your code can be seen clearly on oneNote.
#
# Please make sure the user is `root` and password is `admin` when you submit.
# </div>

# %%
# %reload_ext sql

# %%
# %sql mysql+pymysql://root:admin@localhost/
# %config SqlMagic.style = '_DEPRECATED_DEFAULT'

# %%
# %%sql
# drop database if exists spynetdb;
# create database spynetdb;
# use spynetdb;
#
# create table user (
#     user_id char(32) primary key, -- 1bd31a8ef60e416ba3edd9fc9f8ee4ed
#     email_domain varchar(255) check (
#         email_domain regexp '^[a-zA-Z0-9\.\!\#\$\%\&\*\+\/\=\?\^\_\`\{\|\}\~\-]+$'
#     ), -- https://en.wikipedia.org/wiki/Email_address#Domain
#     email_name varchar(64) check (
#         email_name regexp "^[a-zA-Z0-9!#$%&\'*+/=?^_`{|}~-]+(\\.[a-zA-Z0-9!#$%&\'*+/=?^_`{|}~-]+)*(\\+[a-zA-Z0-9-]+)?$"
#     ), -- https://en.wikipedia.org/wiki/Email_address#Local-part
#     username varchar(64) check (
#         username regexp "^(?=.*[a-zA-Z])[a-z0-9_\\-\\.']{3,30}$" and
#         username not in ('admin', 'root', 'system', 'administrator')
#     ), -- https://support.google.com/a/answer/9193374?hl=en
#     password varchar(4096) check (
#         length(password) >= 6
#     ), -- https://cloud.google.com/identity-platform/docs/password-policy
#     created_at timestamp not null,
#     last_login timestamp,
#     status varchar(16) check (
#         status in ('enabled', 'disabled')
#     ),
#     first_name varchar(128),
#     middle_name varchar(128),
#     last_name varchar(128),
#     phone_num char(11),
#     role varchar(16) check (
#         role in ('user', 'admin')
#     ),
#     verified boolean not null default false,
#     fail_login int not null default 0 check (
#         fail_login >= 0
#     ),
#     twofa boolean not null default false
# );
#
# create table replay (
#     replay_id char(36) primary key, -- 123e4567-e89b-12d3-a456-426614174000
#     start_time timestamp not null, -- 2024-03-29 10:00:00
#     end_time timestamp not null, -- 2024-03-30 10:00:00
#     product varchar(24) check (
#         product in ('Chrome', 'Mozilla', 'AppleWebKit', 'Safari', 'Edge')
#     ), -- Chrome Mozilla AppleWebKit
#     product_version varchar(24) check (
#         product_version regexp '^[0-9]+(\\.[0-9]+)*$'
#     ), -- 91.0.4472.124  5.0  537.36
#     comment varchar(255),  -- this recording is about ...
#     device_type varchar(24) check (
#         device_type in ('Desktop', 'Mobile', 'Unknown')
#     ), -- x
#     os_type varchar(24) check (
#         os_type in ('Windows NT', 'Macintosh', 'Linux', 'iOS', 'Android')
#     ), -- Macintosh; Intel Mac OS X; U; en
#     os_version varchar(16) check (
#         os_version regexp '^[0-9]+(_[0-9]+)*(\\.?[0-9]+)*$'
#     ), -- 13_5_1 10.0 https://developer.mozilla.org/en-US/docs/Web/HTTP/Reference/Headers/User-Agent#chrome_ua_string
#     user_id char(32) not null, -- 3104290294 4802845253
#     network_id varchar(15) check (
#         network_id regexp '^[0-9]{1,3}(\\.[0-9]{1,3}){3}$'
#     ), -- 183.30.196.133 422.225.101.242
#     host_id varchar(4096) check (
#         host_id regexp '^[a-zA-Z0-9-]+(\\.[a-zA-Z0-9-]+)+$'
#     ), -- fonts.googleapis.com huggingface.co
#     d_viewport_height int, -- 1 1320 1680
#     d_viewport_width int, -- 1 1920 2560
#     constraint correct_times check (
#         start_time < end_time
#     ),
#     constraint chk_viewport_height check (
#         d_viewport_height > 0
#     ),
#     constraint chk_viewport_width check (
#         d_viewport_width > 0
#     ),
#     constraint fk_replay_user foreign key (user_id) references user(user_id)
# );
#
# create table webstate (
#     html_hash char(64) primary key check (
#         html_hash regexp '^[a-f0-9]{64}$'
#     )
# );
#
# create table element (
#     uid char(32) primary key check (
#         uid regexp '^[a-f0-9]{32}$'
#     ),
#     html_hash char(64),
#     tag varchar(24),
#     xpath varchar(255), -- path/to/element
#     text varchar(4096), -- some text inside the element
#     xpos int check (xpos >= 0),
#     ypos int check (ypos >= 0),
#     height int check (height > 0),
#     width int check (width > 0),
#     z_index int default 0,
#     foreign key (html_hash) references webstate(html_hash)
# );
#
# create table element_attributes (
#     uid char(32),
#     html_hash char(64),
#     attribute varchar(100),
#     primary key (uid, html_hash, attribute),
#     foreign key (uid) references element(uid),
#     foreign key (html_hash) references webstate(html_hash)
# );
#
# create table cookie (
#     name varchar(256),
#     html_hash char(64),
#     path varchar(256) check (
#         path regexp '^/.*' and
#         length(path) <= 256
#     ), -- minify if exceed 256
#     secure boolean not null default false,
#     http_only boolean not null default false,
#     size int check (size between 1 and 4096),
#     expiry timestamp,
#     domain varchar(4096) check (
#         domain regexp '^[a-zA-Z0-9-]+(\\.[a-zA-Z0-9-]+)+$'
#     ),
#     value varchar(4096),
#     same_site varchar(20) check (
#         same_site in ('Strict', 'Lax', 'None')
#     ),
#     last_accessed timestamp,
#     primary key (name, html_hash),
#     foreign key (html_hash) references webstate(html_hash)
# ); -- https://datatracker.ietf.org/doc/html/draft-ietf-httpbis-rfc6265bis
#
# create table user_event (
#     replay_id char(36),
#     timestamp timestamp,
#     status varchar(16) check (
#         status in ('active', 'complete', 'error')
#     ),
#     source varchar(50),
#     html_hash char(64),
#     viewport_width int check (viewport_width > 0),
#     viewport_height int check (viewport_height > 0),
#     primary key (replay_id, timestamp),
#     foreign key (replay_id) references replay(replay_id),
#     foreign key (html_hash) references webstate(html_hash)
# );
#
# create table element_event (
#     replay_id char(36),
#     timestamp timestamp,
#     primary key (replay_id, timestamp),
#     foreign key (replay_id, timestamp) references user_event(replay_id, timestamp)
# );
#
# create table move_event (
#     replay_id char(36),
#     timestamp timestamp,
#     end_pos_x int check (end_pos_x >= 0),
#     end_pos_y int check (end_pos_y >= 0),
#     start_pos_x int check (start_pos_x >= 0),
#     start_pos_y int check (start_pos_y >= 0),
#     primary key (replay_id, timestamp),
#     foreign key (replay_id, timestamp) references user_event(replay_id, timestamp)
# );
#
# create table scroll_event (
#     replay_id char(36),
#     timestamp timestamp,
#     distance int,
#     primary key (replay_id, timestamp),
#     foreign key (replay_id, timestamp) references user_event(replay_id, timestamp)
# );
#
# create table navigate_event (
#     replay_id char(36),
#     timestamp timestamp,
#     url varchar(4096) check (
#         url regexp '^https?://([a-zA-Z0-9-]+\\.)+[a-zA-Z]{2,}(/.*)?$'
#     ),
#     primary key (replay_id, timestamp),
#     foreign key (replay_id, timestamp) references user_event(replay_id, timestamp)
# );
#
# create table click_event (
#     replay_id char(36),
#     timestamp timestamp,
#     pos_x int check (pos_x >= 0),
#     pos_y int check (pos_y >= 0),
#     mouse_button_id int check (mouse_button_id in (0, 1, 2, 3, 4)), -- https://developer.mozilla.org/en-US/docs/Web/API/MouseEvent/button
#     primary key (replay_id, timestamp),
#     foreign key (replay_id, timestamp) references user_event(replay_id, timestamp)
# );
#
# create table drag_event (
#     replay_id char(36),
#     timestamp timestamp,
#     area int,
#     primary key (replay_id, timestamp),
#     foreign key (replay_id, timestamp) references user_event(replay_id, timestamp)
# );
#
# create table text_event (
#     replay_id char(36),
#     timestamp timestamp,
#     text text,
#     primary key (replay_id, timestamp),
#     foreign key (replay_id, timestamp) references user_event(replay_id, timestamp)
# );
#
# create table event_participating_elements (
#     replay_id char(36),
#     timestamp timestamp,
#     uid char(32),
#     html_hash char(64),
#     primary key (replay_id, timestamp, uid, html_hash),
#     foreign key (replay_id, timestamp) references user_event(replay_id, timestamp),
#     foreign key (uid) references element(uid),
#     foreign key (html_hash) references webstate(html_hash)
# );
# Out:
#  * mysql+pymysql://root:***@localhost/
# 15 rows affected.
# 1 rows affected.
# 0 rows affected.
# 0 rows affected.
# 0 rows affected.
# 0 rows affected.
# 0 rows affected.
# 0 rows affected.
# 0 rows affected.
# 0 rows affected.
# 0 rows affected.
# 0 rows affected.
# 0 rows affected.
# 0 rows affected.
# 0 rows affected.
# 0 rows affected.
# 0 rows affected.
# 0 rows affected.
# []

# %% [markdown]
# ### Section F: Data Population Script

# %% [markdown]
# <div class="alert alert-block alert-warning">
# Fill in relevant code to populate data into your database.
#
# You may populate data using INSERT commands, to bulk load using csv or dat files using pandas (as demonstrated in Assignment 2). No other methods of data loading is allowed.
#
# You are allowed to use online data generator or AI to generate your dataset. But it is your responsibility to check that the dataset is realistic and logically related / coherent. You will be graded by the quality of the data.
# </div>

# %%
import pandas as pd
from sqlalchemy import create_engine

df1 = pd.read_csv('data/user.csv', header=None, quotechar="'")
df2 = pd.read_csv('data/replay.csv', header=None, quotechar="'")
df3 = pd.read_csv('data/webstate.csv', header=None, quotechar="'")
df4 = pd.read_csv('data/element.csv', header=None, quotechar="'")
df5 = pd.read_csv('data/event_participating_elements.csv', header=None, quotechar="'")
df6 = pd.read_csv('data/user_event.csv', header=None, quotechar="'")
df7 = pd.read_csv('data/move_event.csv', header=None, quotechar="'")
df8 = pd.read_csv('data/scroll_event.csv', header=None, quotechar="'")
df9 = pd.read_csv('data/navigate_event.csv', header=None, quotechar="'")
df10 = pd.read_csv('data/click_event.csv', header=None, quotechar="'")
df11 = pd.read_csv('data/drag_event.csv', header=None, quotechar="'")
df12 = pd.read_csv('data/text_event.csv', header=None, quotechar="'")
df13 = pd.read_csv('data/element_attributes.csv', header=None, quotechar="'")
df14 = pd.read_csv('data/cookie.csv', header=None, escapechar='\\', quotechar="'")
df15 = pd.read_csv('data/element_event.csv', header=None, quotechar="'")


df1.columns = ['user_id', 'email_domain', 'email_name', 'username', 'password', 'created_at', 'last_login', 'status', 'first_name', 'middle_name', 'last_name', 'phone_num', 'role', 'verified', 'fail_login', 'twofa']
df2.columns = ['replay_id', 'start_time', 'end_time', 'product', 'product_version', 'comment', 'device_type', 'os_type', 'os_version', 'user_id', 'network_id', 'host_id', 'd_viewport_height', 'd_viewport_width']
df3.columns = ['html_hash']
df4.columns = ['uid', 'html_hash', 'tag', 'xpath', 'text', 'xpos', 'ypos', 'height', 'width', 'z_index']
df5.columns = ['replay_id', 'timestamp', 'uid', 'html_hash']
df6.columns = ['replay_id', 'timestamp', 'status', 'source', 'html_hash', 'viewport_height', 'viewport_width']
df7.columns = ['replay_id', 'timestamp', 'end_pos_x', 'end_pos_y', 'start_pos_x', 'start_pos_y']
df8.columns = ['replay_id', 'timestamp', 'distance']
df9.columns = ['replay_id', 'timestamp', 'url']
df10.columns = ['replay_id', 'timestamp', 'pos_x', 'pos_y', 'mouse_button_id']
df11.columns = ['replay_id', 'timestamp', 'area']
df12.columns = ['replay_id', 'timestamp', 'text']
df13.columns = ['uid', 'html_hash', 'attribute']
df14.columns = ['name', 'html_hash', 'path', 'secure', 'http_only', 'size', 'expiry', 'domain', 'value', 'same_site', 'last_accessed']
df15.columns = ['replay_id', 'timestamp']

# Define datetime columns for each DataFrame
datetime_columns = {
    'df2': ['start_time', 'end_time'],
    'df6': ['timestamp'],
    'df7': ['timestamp'],
    'df8': ['timestamp'],
    'df9': ['timestamp'],
    'df10': ['timestamp'],
    'df11': ['timestamp'],
    'df12': ['timestamp'],
    'df14': ['expiry', 'last_accessed'],
    'df15': ['timestamp']
}

user = 'root'      
password = 'admin'   
host = 'localhost'         
database = 'spynetdb'  

engine = create_engine(f'mysql+pymysql://{user}:{password}@{host}/{database}')

df1.to_sql('user', con=engine, if_exists='append', index=False)
df2.to_sql('replay', con=engine, if_exists='append', index=False)
df3.to_sql('webstate', con=engine, if_exists='append', index=False)
df4.to_sql('element', con=engine, if_exists='append', index=False)
df6.to_sql('user_event', con=engine, if_exists='append', index=False)
df7.to_sql('move_event', con=engine, if_exists='append', index=False)
df8.to_sql('scroll_event', con=engine, if_exists='append', index=False)
df9.to_sql('navigate_event', con=engine, if_exists='append', index=False)
df10.to_sql('click_event', con=engine, if_exists='append', index=False)
df11.to_sql('drag_event', con=engine, if_exists='append', index=False)
df12.to_sql('text_event', con=engine, if_exists='append', index=False)
df13.to_sql('element_attributes', con=engine, if_exists='append', index=False)
df14.to_sql('cookie', con=engine, if_exists='append', index=False)
df15.to_sql('element_event', con=engine, if_exists='append', index=False)
df5.to_sql('event_participating_elements', con=engine, if_exists='append', index=False)

print("Data imported successfully!")
# Out:
# Data imported successfully!

# %% [markdown]
# <div class="alert alert-block alert-warning">
# Add in relevant select statements to show that your data is populated correctly FOR EACH relation, one cell each relation.
# Show only the first 10 records using LIMIT.
# </div>

# %%
# %%sql
# select * from replay limit 10;
# Out:
#  * mysql+pymysql://root:***@localhost/
# 10 rows affected.
# [('01073faa-4318-4316-91c5-96237635231d', datetime.datetime(2024, 3, 1, 14, 45), datetime.datetime(2024, 3, 1, 15, 27, 39), 'Mozilla', '91.0.1', None, 'Unknown', 'Macintosh', '13_1_1', 'd6b6d001d71d4c04b2d9767ff7d0ba42', '172.16.11.12', 'www.example.com', 768, 1366),
#  ('058f86a9-4016-49e0-9b95-6be16cf60e0b', datetime.datetime(2024, 3, 1, 14, 15), datetime.datetime(2024, 3, 1, 14, 48, 37), 'Edge', '129.0.2415.74', 'Bug reproduction', 'Desktop', 'Android', '13.9', '4e7121b0ae7949e192555987dcb6e2ba', '172.16.9.10', 'www.example.com', 1080, 1920),
#  ('1a8bdec2-a200-4d79-9091-8f950d528359', datetime.datetime(2024, 3, 1, 16, 45), datetime.datetime(2024, 3, 1, 17, 32, 51), 'Edge', '139.0.2415.84', None, 'Mobile', 'Android', '13.9', 'd6b6d001d71d4c04b2d9767ff7d0ba42', '172.16.19.20', 'www.example.com', 720, 1280),
# ...

# %%
# %%sql
# select * from webstate limit 10;
# Out:
#  * mysql+pymysql://root:***@localhost/
# 10 rows affected.
# [('05157bf78fcc164f12b663ad20d3363e79a1ecb11b1171345b4da1248f399edd',),
#  ('070008ef42c1abe36107ae1aa9808cc769a1f673694d23f739930f30ba78cf75',),
#  ('09e9fc3cd956ec93874200929558c90f27db93e91e85061a4974b6a03edda537',),
#  ('0f491149ae95d59e6ada1e71dbf8bbdfaf2057dcd22244bf48394b817bd504bf',),
#  ('194c816b320e37623211e4bc97298d52a8fc7b2f3c519300d5417344f1dcb079',),
#  ('1ac2b03e22df6f07376b193fc0e66980a07f6b39541224adae3ea219841f0fb1',),
#  ('1e23114f30859564fa935ac749bb790ad1a06acc0f9f8ec416c24760477d389e',),
#  ('1f0ed76b6aab66bc939c6af89c14d1c4d8b59f419c484d2900b34e7eff12bb37',),
#  ('2376de39f9d16f2eda331165151dfe8f2281caf0a446d6c63a26565ecf8fc45d',),
#  ('2edfeb28707374a80b0371e0e217534776aeab113c81146eea7215fc051cb5f2',)]

# %%
# %%sql
# select * from element limit 10;
# Out:
#  * mysql+pymysql://root:***@localhost/
# 10 rows affected.
# [('00887cf0ac0546d0b38f97d661e5b24f', 'bd746a7f72e48c688cd219518c3fb074765df24d907b6c225519c0ca703f13db', 'span', '/main/section/section/section/section/span[4]', None, 527, 292, 70, 224, 2),
#  ('00bdc9ff27db4f7ea300875ca35eecfd', '77e96e6578776221f909428797758852278b3d0aa8e009583fd6c1e65023e42c', 'h2', "/main/article/section[@class='nav-item']/article[@class='form-control']/section/h2[2]", 'About Us 80', 84, 324, 85, 136, 0),
#  ('00c0def8a3e94bf8a2851d9a2c7a8d4e', '6b4480e65aaeea646446e613b3ca5e8114453afdba8c81a2ea7ec67d9b3bd294', 'p', '/main/article/p[2]', 'Sign Up', 1576, 638, 89, 44, 3),
#  ('019de6f0e7bd421299dae7735aa53a9f', 'db0d022a272b69720e1799664a05c45df4de7b85f2461d8d17ce10e712724ccf', 'a', "/html/article[@class='form-control']/div[@class='form-control']/div/article[@class='container']/section/a[3]", 'Submit', 1024, 578, 74, 266, 3),
# ...

# %%
# %%sql
# select * from event_participating_elements limit 10;
# Out:
#  * mysql+pymysql://root:***@localhost/
# 10 rows affected.
# [('b5f37185-02f6-4df8-9ab7-6131142996e6', datetime.datetime(2024, 3, 1, 12, 31, 15), '00bdc9ff27db4f7ea300875ca35eecfd', '77e96e6578776221f909428797758852278b3d0aa8e009583fd6c1e65023e42c'),
#  ('01073faa-4318-4316-91c5-96237635231d', datetime.datetime(2024, 3, 1, 14, 45, 33), '022287fbc34147b28c6518cb91a70dd4', '77e96e6578776221f909428797758852278b3d0aa8e009583fd6c1e65023e42c'),
#  ('58bf955b-dc96-4977-9169-2ef3e61241fe', datetime.datetime(2024, 3, 1, 12, 20, 33), '029f7cf6a35d4f6b8830eb57ee119464', '31fbb355ad7e68f6ddd84b0438ee9c8b1756df7087f8f933d2209609d92322c1'),
#  ('61ad4a9b-3330-40e9-9532-bbd7fc1dd0a7', datetime.datetime(2024, 3, 1, 15, 3, 16), '029f7cf6a35d4f6b8830eb57ee119464', '31fbb355ad7e68f6ddd84b0438ee9c8b1756df7087f8f933d2209609d92322c1'),
# ...

# %%
# %%sql
# select * from user_event limit 10;
# Out:
#  * mysql+pymysql://root:***@localhost/
# 10 rows affected.
# [('01073faa-4318-4316-91c5-96237635231d', datetime.datetime(2024, 3, 1, 14, 45), 'complete', 'system', '68ca2ff27d35cbb80f23d793ccebbc8bd41d9a56861a99180b41e6189d70905f', 1366, 1366),
#  ('01073faa-4318-4316-91c5-96237635231d', datetime.datetime(2024, 3, 1, 14, 45, 33), 'complete', 'user', 'aa82211395b1980ae9972b75e32c21d8777549e965d02929912baf116d6c9358', 720, 768),
#  ('01073faa-4318-4316-91c5-96237635231d', datetime.datetime(2024, 3, 1, 14, 45, 59), 'active', 'user', '6d9b5027376f482d7e8243fb6b460c35d5eb6d9b57acb4ec02e0222d0d880b76', 1920, 720),
#  ('01073faa-4318-4316-91c5-96237635231d', datetime.datetime(2024, 3, 1, 14, 46, 6), 'complete', 'system', 'bd746a7f72e48c688cd219518c3fb074765df24d907b6c225519c0ca703f13db', 1920, 1280),
#  ('01073faa-4318-4316-91c5-96237635231d', datetime.datetime(2024, 3, 1, 14, 46, 21), 'active', 'system', '1ac2b03e22df6f07376b193fc0e66980a07f6b39541224adae3ea219841f0fb1', 1080, 720),
# ...

# %%
# %%sql
# select * from move_event limit 10;
# Out:
#  * mysql+pymysql://root:***@localhost/
# 10 rows affected.
# [('01073faa-4318-4316-91c5-96237635231d', datetime.datetime(2024, 3, 1, 14, 45, 59), 1643, 553, 1467, 196),
#  ('01073faa-4318-4316-91c5-96237635231d', datetime.datetime(2024, 3, 1, 14, 47, 14), 455, 231, 1076, 1058),
#  ('058f86a9-4016-49e0-9b95-6be16cf60e0b', datetime.datetime(2024, 3, 1, 14, 17, 16), 453, 940, 1746, 409),
#  ('058f86a9-4016-49e0-9b95-6be16cf60e0b', datetime.datetime(2024, 3, 1, 14, 21, 3), 611, 551, 126, 198),
#  ('1a8bdec2-a200-4d79-9091-8f950d528359', datetime.datetime(2024, 3, 1, 16, 53, 21), 157, 461, 39, 412),
#  ('1af81360-1632-40a6-a5fd-5c6de537fe39', datetime.datetime(2024, 3, 1, 15, 15, 40), 660, 1154, 645, 170),
#  ('1af81360-1632-40a6-a5fd-5c6de537fe39', datetime.datetime(2024, 3, 1, 15, 18, 23), 38, 113, 761, 441),
#  ('1af81360-1632-40a6-a5fd-5c6de537fe39', datetime.datetime(2024, 3, 1, 15, 19, 37), 587, 808, 23, 369),
# ...

# %%
# %%sql
# select * from scroll_event limit 10;
# Out:
#  * mysql+pymysql://root:***@localhost/
# 10 rows affected.
# [('058f86a9-4016-49e0-9b95-6be16cf60e0b', datetime.datetime(2024, 3, 1, 14, 15, 56), 188),
#  ('058f86a9-4016-49e0-9b95-6be16cf60e0b', datetime.datetime(2024, 3, 1, 14, 18, 14), 140),
#  ('1a8bdec2-a200-4d79-9091-8f950d528359', datetime.datetime(2024, 3, 1, 16, 46, 26), -369),
#  ('1a8bdec2-a200-4d79-9091-8f950d528359', datetime.datetime(2024, 3, 1, 16, 48, 35), -332),
#  ('1a8bdec2-a200-4d79-9091-8f950d528359', datetime.datetime(2024, 3, 1, 16, 50, 44), -117),
#  ('1a8bdec2-a200-4d79-9091-8f950d528359', datetime.datetime(2024, 3, 1, 16, 52, 9), -171),
#  ('1af81360-1632-40a6-a5fd-5c6de537fe39', datetime.datetime(2024, 3, 1, 15, 16, 16), -450),
#  ('1af81360-1632-40a6-a5fd-5c6de537fe39', datetime.datetime(2024, 3, 1, 15, 17, 9), -473),
#  ('1af81360-1632-40a6-a5fd-5c6de537fe39', datetime.datetime(2024, 3, 1, 15, 19, 54), -394),
#  ('1c53befb-69ae-458e-891d-5c28752a0d1f', datetime.datetime(2024, 3, 1, 14, 2, 47), -479)]

# %%
# %%sql
# select * from navigate_event limit 10;
# Out:
#  * mysql+pymysql://root:***@localhost/
# 10 rows affected.
# [('058f86a9-4016-49e0-9b95-6be16cf60e0b', datetime.datetime(2024, 3, 1, 14, 19, 18), 'https://api.example.com/products'),
#  ('1a8bdec2-a200-4d79-9091-8f950d528359', datetime.datetime(2024, 3, 1, 16, 45, 35), 'https://api.example.com/contact'),
#  ('1a8bdec2-a200-4d79-9091-8f950d528359', datetime.datetime(2024, 3, 1, 16, 47, 16), 'https://api.example.com/home'),
#  ('1a8bdec2-a200-4d79-9091-8f950d528359', datetime.datetime(2024, 3, 1, 16, 48, 11), 'https://api.example.com/contact'),
#  ('1a8bdec2-a200-4d79-9091-8f950d528359', datetime.datetime(2024, 3, 1, 16, 50, 15), 'https://app.example.com/home'),
#  ('1a8bdec2-a200-4d79-9091-8f950d528359', datetime.datetime(2024, 3, 1, 16, 51, 15), 'https://api.example.com/home'),
#  ('1a8bdec2-a200-4d79-9091-8f950d528359', datetime.datetime(2024, 3, 1, 16, 54, 17), 'https://app.example.com/contact'),
# ...

# %%
# %%sql
# select * from click_event limit 10;
# Out:
#  * mysql+pymysql://root:***@localhost/
# 10 rows affected.
# [('1a8bdec2-a200-4d79-9091-8f950d528359', datetime.datetime(2024, 3, 1, 16, 52, 43), 610, 388, 1),
#  ('1af81360-1632-40a6-a5fd-5c6de537fe39', datetime.datetime(2024, 3, 1, 15, 15, 34), 280, 36, 1),
#  ('1c53befb-69ae-458e-891d-5c28752a0d1f', datetime.datetime(2024, 3, 1, 14, 0, 29), 591, 1620, 2),
#  ('1c53befb-69ae-458e-891d-5c28752a0d1f', datetime.datetime(2024, 3, 1, 14, 2, 23), 1915, 1143, 1),
#  ('27d7803a-7a49-4bac-bca1-27a1758d4486', datetime.datetime(2024, 3, 1, 14, 30, 58), 114, 917, 1),
#  ('58bf955b-dc96-4977-9169-2ef3e61241fe', datetime.datetime(2024, 3, 1, 12, 18, 10), 1235, 216, 0),
#  ('5d3ebf9c-d425-4123-a4cd-1f8745201186', datetime.datetime(2024, 3, 1, 16, 0, 34), 642, 76, 1),
#  ('5d3ebf9c-d425-4123-a4cd-1f8745201186', datetime.datetime(2024, 3, 1, 16, 4, 43), 204, 880, 2),
#  ('71824811-0b8a-4f7e-9cdc-52f71d026de6', datetime.datetime(2024, 3, 1, 15, 45, 43), 1230, 1507, 2),
# ...

# %%
# %%sql
# select * from drag_event limit 10;
# Out:
#  * mysql+pymysql://root:***@localhost/
# 10 rows affected.
# [('01073faa-4318-4316-91c5-96237635231d', datetime.datetime(2024, 3, 1, 14, 46, 55), 144),
#  ('01073faa-4318-4316-91c5-96237635231d', datetime.datetime(2024, 3, 1, 14, 48, 8), 44),
#  ('058f86a9-4016-49e0-9b95-6be16cf60e0b', datetime.datetime(2024, 3, 1, 14, 16, 5), 143),
#  ('058f86a9-4016-49e0-9b95-6be16cf60e0b', datetime.datetime(2024, 3, 1, 14, 17, 53), 144),
#  ('058f86a9-4016-49e0-9b95-6be16cf60e0b', datetime.datetime(2024, 3, 1, 14, 18, 43), 238),
#  ('058f86a9-4016-49e0-9b95-6be16cf60e0b', datetime.datetime(2024, 3, 1, 14, 19, 24), 165),
#  ('058f86a9-4016-49e0-9b95-6be16cf60e0b', datetime.datetime(2024, 3, 1, 14, 20, 29), 144),
#  ('1a8bdec2-a200-4d79-9091-8f950d528359', datetime.datetime(2024, 3, 1, 16, 49, 16), 140),
#  ('1af81360-1632-40a6-a5fd-5c6de537fe39', datetime.datetime(2024, 3, 1, 15, 20, 24), 198),
#  ('1af81360-1632-40a6-a5fd-5c6de537fe39', datetime.datetime(2024, 3, 1, 15, 21, 12), 169)]

# %%
# %%sql
# select * from text_event limit 10;
# Out:
#  * mysql+pymysql://root:***@localhost/
# 10 rows affected.
# [('01073faa-4318-4316-91c5-96237635231d', datetime.datetime(2024, 3, 1, 14, 46, 21), 'Search query'),
#  ('01073faa-4318-4316-91c5-96237635231d', datetime.datetime(2024, 3, 1, 14, 47, 5), 'Comment text'),
#  ('058f86a9-4016-49e0-9b95-6be16cf60e0b', datetime.datetime(2024, 3, 1, 14, 16, 40), 'Comment text'),
#  ('058f86a9-4016-49e0-9b95-6be16cf60e0b', datetime.datetime(2024, 3, 1, 14, 19, 45), 'Search query'),
#  ('058f86a9-4016-49e0-9b95-6be16cf60e0b', datetime.datetime(2024, 3, 1, 14, 21, 22), 'Test input'),
#  ('1c53befb-69ae-458e-891d-5c28752a0d1f', datetime.datetime(2024, 3, 1, 14, 0, 36), 'Test input'),
#  ('27d7803a-7a49-4bac-bca1-27a1758d4486', datetime.datetime(2024, 3, 1, 14, 34, 23), 'Search query'),
#  ('58bf955b-dc96-4977-9169-2ef3e61241fe', datetime.datetime(2024, 3, 1, 12, 16, 26), 'Comment text'),
#  ('5d3ebf9c-d425-4123-a4cd-1f8745201186', datetime.datetime(2024, 3, 1, 16, 1, 43), 'Test input'),
# ...

# %%
# %%sql
# select * from element_event limit 10;
# Out:
#  * mysql+pymysql://root:***@localhost/
# 10 rows affected.
# [('01073faa-4318-4316-91c5-96237635231d', datetime.datetime(2024, 3, 1, 14, 45, 33)),
#  ('01073faa-4318-4316-91c5-96237635231d', datetime.datetime(2024, 3, 1, 14, 46, 6)),
#  ('01073faa-4318-4316-91c5-96237635231d', datetime.datetime(2024, 3, 1, 14, 47, 13)),
#  ('01073faa-4318-4316-91c5-96237635231d', datetime.datetime(2024, 3, 1, 14, 48, 19)),
#  ('01073faa-4318-4316-91c5-96237635231d', datetime.datetime(2024, 3, 1, 14, 49, 26)),
#  ('01073faa-4318-4316-91c5-96237635231d', datetime.datetime(2024, 3, 1, 14, 49, 59)),
#  ('01073faa-4318-4316-91c5-96237635231d', datetime.datetime(2024, 3, 1, 14, 50, 33)),
#  ('01073faa-4318-4316-91c5-96237635231d', datetime.datetime(2024, 3, 1, 14, 51, 39)),
#  ('01073faa-4318-4316-91c5-96237635231d', datetime.datetime(2024, 3, 1, 14, 53, 19)),
#  ('01073faa-4318-4316-91c5-96237635231d', datetime.datetime(2024, 3, 1, 14, 54, 26))]

# %%
# %%sql
# select * from cookie limit 10;
# Out:
#  * mysql+pymysql://root:***@localhost/
# 10 rows affected.
# [('ab_test', '77e96e6578776221f909428797758852278b3d0aa8e009583fd6c1e65023e42c', '/account', 1, 1, 2228, datetime.datetime(2025, 6, 5, 10, 8, 31), 'api010.testorg.com', 'variant_B', None, datetime.datetime(2025, 3, 31, 7, 37, 31)),
#  ('ab_test', 'bfe06323c194fb42b4aff9d0545e4767ee45dd1136effbd3c62fdc97a684ff1c', '/', 1, 1, 3008, datetime.datetime(2026, 2, 16, 10, 8, 31), 'www.example.net', 'variant_B', 'Lax', datetime.datetime(2025, 3, 30, 23, 33, 31)),
#  ('auth_token', 'a2d0e539e8faebd8432af14a40971cede4c2169d1473feace956648a9eb5d96f', '/', 0, 1, 1869, datetime.datetime(2025, 5, 2, 10, 8, 31), 'api016.testorg.com', 'eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.29bf2e9c-aeb8-4f94-874f-2ae2f5b7fd13', 'Lax', datetime.datetime(2025, 3, 30, 19, 47, 31)),
# ...

# %%
# %%sql
# select * from element_attributes limit 10;
# Out:
#  * mysql+pymysql://root:***@localhost/
# 10 rows affected.
# [('1c8caaf9290643269b34cc1e46efe584', '05157bf78fcc164f12b663ad20d3363e79a1ecb11b1171345b4da1248f399edd', 'data-section=cta'),
#  ('1c8caaf9290643269b34cc1e46efe584', '05157bf78fcc164f12b663ad20d3363e79a1ecb11b1171345b4da1248f399edd', 'id=main-6416'),
#  ('103bb5f20fd44bcd813968ceb2603ea8', '070008ef42c1abe36107ae1aa9808cc769a1f673694d23f739930f30ba78cf75', 'download='),
#  ('103bb5f20fd44bcd813968ceb2603ea8', '070008ef42c1abe36107ae1aa9808cc769a1f673694d23f739930f30ba78cf75', 'hreflang=fr-FR'),
#  ('103bb5f20fd44bcd813968ceb2603ea8', '070008ef42c1abe36107ae1aa9808cc769a1f673694d23f739930f30ba78cf75', 'rel=noopener noreferrer'),
#  ('31ef19f9878846de80dbe0e4e0c929db', '070008ef42c1abe36107ae1aa9808cc769a1f673694d23f739930f30ba78cf75', 'aria-hidden=true'),
#  ('036a8ef32f15497697cbdc0804ccfacc', '09e9fc3cd956ec93874200929558c90f27db93e91e85061a4974b6a03edda537', 'method=get'),
# ...

# %%
# %%sql
# select * from user limit 10;
# Out:
#  * mysql+pymysql://root:***@localhost/
# 10 rows affected.
# [('001ecf8afc9649c58b5e94b570cd8356', 'mail.io', 'olivia14', 'olivia14', '0l!v!@14', datetime.datetime(2024, 2, 5, 15, 30, 25), datetime.datetime(2024, 5, 29, 10, 45, 55), 'enabled', 'Olivia', 'Grace', 'Walker', '1832555445', 'user', 1, 0, 1),
#  ('1bd31a8ef60e416ba3edd9fc9f8ee4ed', 'gmail.com', 'aliceandbob', 'aliceandbobBFF0011153', 'qwertyuiop', datetime.datetime(2023, 1, 15, 11, 34, 22), datetime.datetime(2024, 6, 10, 14, 22, 17), 'enabled', 'Alice', 'and', 'Bob', '1202555018', 'admin', 1, 0, 0),
#  ('20cda338ba4c4eaeacba82d14cf713fb', 'password.test', 'test18', 'pwd_user7', 'V@lid1234', datetime.datetime(2024, 5, 28, 9, 50, 25), datetime.datetime(2024, 6, 9, 9, 20, 35), 'disabled', 'Lucas', 'James', 'Carter', '1617555667', 'user', 1, 1, 0),
# ...

# %% [markdown]
# ### Section G: Stored Program & Queries Script

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>SQL Query:</b> <br>
#
# * Pose 2 interesting queries asked by administrator and 2 from user of your domain. Write SELECT queries to answer them. State the question that is being asked for each query, and also a short explanation of why the question is relevant to the administrator and user of the domain. If relevant, you may wish to implement the query as a stored procedure or function.
#
# * Write the full SELECT statement that answers the query.
#
# * Each query must be sufficiently complex (join of a few tables, use of aggregate functions, nested queries etc). These queries must be USEFUL and must be implemented in your final web interface (displayed when administor or user logs in).
#
# * Finally, show a copy of the result set produced by each query.
#
# * Please ensure your code can be seen clearly from oneNote.
#
# </div>

# %% [markdown]
# #### Admin Query 1

# %% [markdown]
# For each user query the average duration of their recordings and then sort them in descending order. This is useful for the admin to monitor the duration of the recordings logged by users, allowing them to check for excess logging. If an admin wants to find out where a users stands in terms of how long they have recorded compared to other people, it will be useful if they can query the average duration of recordings, for use in some data display metric we can implement in the front end.

# %%
# %%sql
# select
#     u.user_id,
#     u.username,
#     avg(timestampdiff(second, r.start_time, r.end_time)) as avg_duration
# from replay r
# join user u on r.user_id = u.user_id
# group by u.user_id, u.username
# order by avg_duration desc
# limit 10;
# Out:
#  * mysql+pymysql://root:***@localhost/
# 3 rows affected.
# [('4e7121b0ae7949e192555987dcb6e2ba', 'picokatx_official', Decimal('1836.5556')),
#  ('d6b6d001d71d4c04b2d9767ff7d0ba42', 'ang_wei_bin_official', Decimal('1705.6000')),
#  ('1bd31a8ef60e416ba3edd9fc9f8ee4ed', 'aliceandbobBFF0011153', Decimal('1043.0000'))]

# %% [markdown]
# #### Admin Query 2

# %% [markdown]
# For each user calculate the average number of elements they interact with per recording. This allows the admins to see which users are more interactive with the websites. The admin can also use this to track abnormally high or abnormally low elements interacted in a recording so check for suspicious behaivior.

# %%
# %%sql
# select
#     u.user_id,
#     u.username,
#     (select avg(t1.b) from (select count(e.uid) as b from
#      (select r.replay_id as replay_id from replay r where r.user_id = u.user_id) as t, event_participating_elements e
#     where t.replay_id = e.replay_id
#     group by t.replay_id) as t1)
# from user u;
# Out:
#  * mysql+pymysql://root:***@localhost/
# 31 rows affected.
# [('001ecf8afc9649c58b5e94b570cd8356', 'olivia14', None),
#  ('1bd31a8ef60e416ba3edd9fc9f8ee4ed', 'aliceandbobBFF0011153', Decimal('9.0000')),
#  ('20cda338ba4c4eaeacba82d14cf713fb', 'pwd_user7', None),
#  ('2508785a05b843bab8c9e17411e5460a', 'pwd_user6', None),
#  ('27b20cca0dc646369746fe67ace83835', 'pwd_user9', None),
#  ('29582fdf84734db198e5aed54ffe7348', 'pwd_user10', None),
#  ('42876168f2a6472ea08a688ca6264ff2', 'tom_11', None),
#  ('4889555d0d17418b88b84556448c5457', 'usr1', None),
#  ('4e7121b0ae7949e192555987dcb6e2ba', 'picokatx_official', Decimal('11.4444')),
#  ('56a701bc8caf41bcad26f85f8b14d052', 'john_doe1', None),
#  ('5cae6bfd7ec64302b3eb9c46c35deddf', 'noah17', None),
#  ('73c389f2a3884db5942f9694242701e2', 'mike.c5', None),
#  ('84d8ece3efd5476aae13b86fa40a278a', 'usr2', None),
#  ('886dc2571be9407197f9d0fe957f5087', 'usr5', None),
#  ('917f898ef36a4371bfbc4d26799099e4', 'user_max', None),
# ...

# %% [markdown]
# #### User Query 1

# %% [markdown]
# For a specific user, query the distribution of different products used in their replays. This is useful for users to track which products they use most on the website.

# %%
# %%sql
# select r.product, count(*)/ (select count(*) from replay r where r.user_id = "d6b6d001d71d4c04b2d9767ff7d0ba42") as percentage
# from replay r
# where r.user_id = "d6b6d001d71d4c04b2d9767ff7d0ba42"
# group by r.product;
# Out:
#  * mysql+pymysql://root:***@localhost/
# 4 rows affected.
# [('Mozilla', Decimal('0.4000')),
#  ('Edge', Decimal('0.2000')),
#  ('Safari', Decimal('0.2000')),
#  ('Chrome', Decimal('0.2000'))]

# %% [markdown]
# #### User Query 2

# %% [markdown]
# Find the total number of times each element that is clicked atleast once has been clicked. This allows users to analyze which elements are most commonly clicked for data analysis purposes. This will be extended to only include certain chosen elements in the final product.

# %%
# %%sql
# select uid, count(*)
# from click_event c, event_participating_elements e
# where c.replay_id = e.replay_id and c.timestamp = e.timestamp
# group by uid;
# Out:
#  * mysql+pymysql://root:***@localhost/
# 9 rows affected.
# [('03c9d8fbdd29491490a0a24261bc26f8', 1),
#  ('0d5d4bf7748c4154921efab8981af04d', 1),
#  ('5745fbf1c0ae47029e028d873fc3cda5', 1),
#  ('6acac4f170bd4cc8b3e671821b7fe1ca', 1),
#  ('704677fa01364cce9b5087a41f09b7cb', 1),
#  ('9ea4fefd884a47fe96e931bb2e45121e', 1),
#  ('e47b6efe9a2241a893d32f237c47059b', 1),
#  ('f237f0ffe8824401a46aa1e376f7e0d4', 1),
#  ('f2e5ebfb946240349d0960393c961476', 1)]

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Triggers and Events:</b> <br>
# Shortlist relevant triggers or scheduled events that are useful for your database system.
# Describe what the trigger/event is for and why it is useful for your DB.
# </div>

# %% [markdown]
# #### Trigger/Event

# %% [markdown]
# When a user starts a recording of their browsing session, we will initiate a new replay. This wil allow us to further populate the database with information about the replay as the user records.

# %%
# %%sql
# insert into replay values
# (
#     "61ad4a9b-3330-40e9-9532-bbd7fc1dd0a8",
#     "2024-03-01 15:00:00",
#     "2024-03-01 15:03:27",
#     "AppleWebKit",
#     "612.2",
#     "User flow analysis",
#     "Desktop",
#     "Linux",
#     "5.19.0.12",
#     "d6b6d001d71d4c04b2d9767ff7d0ba42",
#     "172.16.12.13",
#     "api012.testorg.com",
#     1080,
#     1920
# );
# Out:
#  * mysql+pymysql://root:***@localhost/
# 1 rows affected.
# []

# %% [markdown]
# Used for when a user wants to update their personal details on the website. Here, a user has edited their personal details, and clicked submit. In the backend, a sql update query is composed from the changed particulars and executed.

# %%
# %%sql
# update user set phone_num = "6593275353",
# first_name = "David",
# middle_name = "Baker",
# last_name = "Brown",
# email_domain = "gmail.com",
# email_name = "david.brown",
# status = "disabled"
# where user_id = "d6b6d001d71d4c04b2d9767ff7d0ba42";
# Out:
#  * mysql+pymysql://root:***@localhost/
# 1 rows affected.
# []

# %% [markdown]
# ### Section H: Draft of UI and Functions

# %% [markdown]
# <div class="alert alert-block alert-warning">
# Give a screen shot of your draft UI. In particular, list down how the 4 queries shortlisted above can be accessed via the UI.
#
# Finally, shortlist other functions you plan to implement in the final frontend implementation phase.
#
# Note that this section will NOT have a grade. It is more to advise on scope for the final phase.
# </div>

# %% [markdown]
# #### Draft Sketch of UI

# %% [markdown]
# <img src="CS6131-Project-DraftUI.png">

# %% [markdown]
# #### Functionalities of Front-End

# %% [markdown]
# * Manually run SQL Command through run command dropdown so as to execute the 4 queries shortlisted above

# %% [markdown]
# ### Contribution Log

# %% [markdown]
# <div class="alert alert-block alert-warning">
# Clearly state the contribution of each member below:
# </div>

# %% [markdown]
# Ang Wei Bin

# %% [markdown]
# | Task/Module               | Contribution Details                |
# |---------------------------|-------------------------------------|
# | Executive Summary           | Made advised changes |
# | Relational Schema Design  | Converted ER model to schema        |
# | Buisness Rules | Made advised changes |
# | Stored Program & Queries Script | Made most of the SQL code,and most of the explanation |

# %% [markdown]
# Theophilus Lee Khong Yoon

# %% [markdown]
# | Task/Module               | Contribution Details                             |
# |---------------------------|--------------------------------------------------|
# | ER Model Design           | Made advised changes, added more user attributes |
# | Relational Schema Design  | Made advised changes, added more user attributes |
# | DDL Schema                | Wrote all the sql create tables                  |
# | Data Population Script    | Wrote all the data population script             |
# | Draft UI                  | Took screenshot of draft ui             |

# %% [markdown]
# ### Citations

# %% [markdown]
# <div class="alert alert-block alert-warning">
# Indicated any references used. If AI is used, please share the full chatlog.
# </div>

# %% [markdown]
# ### Citations
# Deepnote's text autocompletion feature (.powered by codium) was used for writing this document. Deepseek R1, Claude 3.7 sonnet thinking, gemini 2.5 fast thinking exp and Cursor Tab were also used for autocompletion on the Business Rules, scaffolding of the DDL schema, and generation of data. ChatGPT was used for ideation and research.
#
# **ChatGPT Logs**
# - https://chatgpt.com/share/67a87226-b150-8000-8717-41dc5aca7a2e
# - https://chatgpt.com/share/67a87245-7ff4-8000-af5a-8f63591a5159
# - https://chatgpt.com/share/67a87255-c54c-8000-a0f1-89209bc8481e
# - https://chatgpt.com/share/67a8726f-fac4-8000-a6f8-309bdc94381b
# - https://chatgpt.com/share/67a8732b-3ac8-8002-a733-e4c97b819bc3

# %% [markdown]
# <hr>
# © NUS High School of Math & Science

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=3fe41874-99e0-4e33-9fd6-e7ae9af26c36' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
